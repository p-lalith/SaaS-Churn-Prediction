# %% [markdown]
# # RavenStack Churn – Main Analysis
# EDA → Models → Visuals → CSV export.

# %%
import pandas as pd
df = pd.read_csv('ravenstack_flat_churn.csv')
df.shape, df.head()

# %%
# (Add your EDA/modeling here)
print('Placeholder notebook: use the full version in your workspace if needed.')

# %%
# 🔽 Export scored customers for LoVable (assumes 'scored_customers.csv' exists or variable 'df_test_out')
import pandas as pd
try:
    out = pd.read_csv('scored_customers.csv')
    print('Scored CSV present:', out.shape)
except Exception as e:
    print('No scored file found yet:', e)
